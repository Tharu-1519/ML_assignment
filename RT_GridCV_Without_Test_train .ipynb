# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],'n_estimators':[10,100,1000,2000,3000],'max_features':['sqrt','log2']}
grid=GridSearchCV(RandomForestRegressor(),param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100, 1000, 2000, 3000]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score values for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score values for best parameter {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.114832      0.003757         0.014558        0.001653
# 1        0.973635      0.015460         0.043973        0.002481
# 2        9.236782      0.049003         0.335423        0.014114
# 3       18.881417      0.106182         0.745009        0.032263
# 4       28.271349      0.386530         1.050746        0.052364
# 5        0.119231      0.020306         0.012291        0.000671
# 6        0.950388      0.051778         0.044837        0.002706
# 7        9.968683      0.356205         0.366692        0.037540
# 8       18.408815      0.204666         0.678871        0.026212
# 9       27.377447      0.202805         1.044247        0.067662
# 10       0.311325      0.014131         0.011709        0.001227
# 11       3.085052      0.049817         0.045562        0.011180
# 12      30.650780      0.501075         0.316315        0.007754
# 13      60.437913      0.388391         0.684694        0.067096
# 14      91.292842      0.678769         0.929628        0.045522
# 15       0.316670      0.016546         0.011240        0.000403
# 16       3.382606      0.366307         0.068715        0.032277
# 17      30.985948      0.977556         0.311605        0.004705
# 18      59.440949      0.395996         0.611262        0.018725
# 19      90.049993      1.256694         0.941377        0.013417
# 20       0.105126      0.017526         0.013407        0.005590
# 21       0.900895      0.018944         0.044794        0.007398
# 22       9.242709      0.147011         0.372276        0.065743
# 23      17.805638      0.067201         0.657904        0.017623
# 24      26.887388      0.207071         0.984387        0.043191
# 25       0.110921      0.013157         0.011288        0.000468
# 26       0.914820      0.014535         0.041766        0.001589
# 27       9.053085      0.156558         0.347176        0.015267
# 28      18.124231      0.131818         0.673412        0.037564
# 29      27.215540      0.321076         1.011627        0.032892
# 30       0.114425      0.002969         0.011998        0.001647
# 31       1.059680      0.076597         0.042970        0.003719
# 32      10.094005      0.095628         0.352656        0.010627
# 33      21.831066      0.562352         0.649610        0.010898
# 34      31.124925      0.708094         0.992558        0.016802
# 35       0.123392      0.024643         0.011429        0.000663
# 36       1.046499      0.010376         0.045348        0.005908
# 37      10.557245      0.212137         0.347027        0.033316
# 38      20.654181      0.540797         0.680371        0.036797
# 39      25.325969      2.948663         0.653097        0.075096
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                100
# 2    squared_error               sqrt               1000
# 3    squared_error               sqrt               2000
# 4    squared_error               sqrt               3000
# 5    squared_error               log2                 10
# 6    squared_error               log2                100
# 7    squared_error               log2               1000
# 8    squared_error               log2               2000
# 9    squared_error               log2               3000
# 10  absolute_error               sqrt                 10
# 11  absolute_error               sqrt                100
# 12  absolute_error               sqrt               1000
# 13  absolute_error               sqrt               2000
# 14  absolute_error               sqrt               3000
# 15  absolute_error               log2                 10
# 16  absolute_error               log2                100
# 17  absolute_error               log2               1000
# 18  absolute_error               log2               2000
# 19  absolute_error               log2               3000
# 20    friedman_mse               sqrt                 10
# 21    friedman_mse               sqrt                100
# 22    friedman_mse               sqrt               1000
# 23    friedman_mse               sqrt               2000
# 24    friedman_mse               sqrt               3000
# 25    friedman_mse               log2                 10
# 26    friedman_mse               log2                100
# 27    friedman_mse               log2               1000
# 28    friedman_mse               log2               2000
# 29    friedman_mse               log2               3000
# 30         poisson               sqrt                 10
# 31         poisson               sqrt                100
# 32         poisson               sqrt               1000
# 33         poisson               sqrt               2000
# 34         poisson               sqrt               3000
# 35         poisson               log2                 10
# 36         poisson               log2                100
# 37         poisson               log2               1000
# 38         poisson               log2               2000
# 39         poisson               log2               3000
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.837829
# 1   {'criterion': 'squared_error', 'max_features':...           0.857049
# 2   {'criterion': 'squared_error', 'max_features':...           0.859826
# 3   {'criterion': 'squared_error', 'max_features':...           0.859966
# 4   {'criterion': 'squared_error', 'max_features':...           0.859848
# 5   {'criterion': 'squared_error', 'max_features':...           0.837378
# 6   {'criterion': 'squared_error', 'max_features':...           0.856393
# 7   {'criterion': 'squared_error', 'max_features':...           0.859062
# 8   {'criterion': 'squared_error', 'max_features':...           0.859264
# 9   {'criterion': 'squared_error', 'max_features':...           0.859859
# 10  {'criterion': 'absolute_error', 'max_features'...           0.834517
# 11  {'criterion': 'absolute_error', 'max_features'...           0.855866
# 12  {'criterion': 'absolute_error', 'max_features'...           0.858691
# 13  {'criterion': 'absolute_error', 'max_features'...           0.859257
# 14  {'criterion': 'absolute_error', 'max_features'...           0.858866
# 15  {'criterion': 'absolute_error', 'max_features'...           0.829039
# 16  {'criterion': 'absolute_error', 'max_features'...           0.855206
# 17  {'criterion': 'absolute_error', 'max_features'...           0.857926
# 18  {'criterion': 'absolute_error', 'max_features'...           0.858911
# 19  {'criterion': 'absolute_error', 'max_features'...           0.858944
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.858151
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.862884
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.859428
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.859475
# 24  {'criterion': 'friedman_mse', 'max_features': ...           0.859776
# 25  {'criterion': 'friedman_mse', 'max_features': ...           0.838734
# 26  {'criterion': 'friedman_mse', 'max_features': ...           0.858396
# 27  {'criterion': 'friedman_mse', 'max_features': ...           0.859532
# 28  {'criterion': 'friedman_mse', 'max_features': ...           0.859575
# 29  {'criterion': 'friedman_mse', 'max_features': ...           0.859558
# 30  {'criterion': 'poisson', 'max_features': 'sqrt...           0.847065
# 31  {'criterion': 'poisson', 'max_features': 'sqrt...           0.856922
# 32  {'criterion': 'poisson', 'max_features': 'sqrt...           0.859189
# 33  {'criterion': 'poisson', 'max_features': 'sqrt...           0.859230
# 34  {'criterion': 'poisson', 'max_features': 'sqrt...           0.859454
# 35  {'criterion': 'poisson', 'max_features': 'log2...           0.846625
# 36  {'criterion': 'poisson', 'max_features': 'log2...           0.857878
# 37  {'criterion': 'poisson', 'max_features': 'log2...           0.860242
# 38  {'criterion': 'poisson', 'max_features': 'log2...           0.860155
# 39  {'criterion': 'poisson', 'max_features': 'log2...           0.860109
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0